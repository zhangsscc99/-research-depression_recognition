# %%
# %%
# Loading all necessary libraries and modules
import os
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
# Set the TensorFlow backend to use the GPU
tf.config.experimental.set_visible_devices([], 'GPU')
from matplotlib import gridspec

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import *
from tensorflow.keras.models import Model

from keras.utils.np_utils import to_categorical
#from keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.callbacks import ModelCheckpoint

#from sklearn.utils import shuffle
#from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow.keras as keras

# %%
base_model = VGG16(weights='imagenet', include_top=False)

# Add a new top layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
#x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='linear')(x)

# Create a new model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
import os
big_folder='/Users/mac/Desktop/implementation_depression/20-50/test'
big_dirs=os.listdir(big_folder)
big_paths=[]
for i in range(len(big_dirs)):
    big_paths.append(big_folder+'/'+big_dirs[i])

# %%
big_paths
# Out:
# ['/Users/mac/Desktop/implementation_depression/20-50/test/50',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/32',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/35',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/34',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/33',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/20',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/27',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/29',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/42',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/45',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/28',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/26',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/21',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/44',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/43',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/38',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/36',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/31',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/30',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/37',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/39',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/46',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/41',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/48',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/24',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/23',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/49',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/40',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/47',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/22',
#  '/Users/mac/Desktop/implementation_depression/20-50/test/25']

# %%
orig = cv.imread('/Users/mac/Desktop/implementation_depression/20-50/test/20/28492.jpg')

    # Convert image to RGB from BGR (another way is to use "image = image[:, :, ::-1]" code)
orig = cv.cvtColor(orig, cv.COLOR_BGR2RGB)

# Resize image to 224x224 size
image = cv.resize(orig, (224, 224)).reshape(-1, 224, 224, 3)

# %%
import os 
single_folder=big_paths[0]
dirs=os.listdir(single_folder)
paths=[]
for i in range(len(dirs)):
    
    paths.append(single_folder+'/'+dirs[i])

#paths

# %%
import cv2 as cv

# %%
biglst=[]
for i in range(len(paths)):
    orig = cv.imread(paths[i])

    # Convert image to RGB from BGR (another way is to use "image = image[:, :, ::-1]" code)
    orig = cv.cvtColor(orig, cv.COLOR_BGR2RGB)

    # Resize image to 224x224 size
    image = cv.resize(orig, (224, 224)).reshape(-1, 224, 224, 3)

    # We need to preprocess imageto fulfill ResNet50 requirements
    image = preprocess_input(image)

    # Extracting our features
    features = model.predict(image)
    toaddlst=np.ndarray.tolist(features[0])
    biglst.append(toaddlst)


    features.shape

# %%
features.shape

# %%
features[0]

# %%
import numpy as np
lst=np.ndarray.tolist(features[0])

# %%

# %%
#features[0][0][0]
#for i in range(len(features[0][0][0])):
#   print(features[0][0][0][i])

# %%

field=['name','timestamp']
for i in range(2048):
    field.append('neuron_'+str(i))

# %%


        

# %%
#!scp -r /Users/mac/Desktop/implementation_depression/cropped_aligned yw4554@greene.hpc.nyu.edu:/scratch/yw4554/implementation_depression

# %%
#scp /users/mac/desktop/cropped_aligned.zip yw4554@greene.hpc.nyu.edu:/scratch/yw4554/im_de
#scp /users/mac/desktop/20-50.zip yw4554@greene.hpc.nyu.edu:/scratch/yw4554/im_de/implementation_depression
#scp /users/mac/desktop/implementation_depression/depression_modelsave/resnet50_test.py yw4554@greene.hpc.nyu.edu:/scratch/yw4554/im_de_url/implementation_depression
#scp /users/mac/desktop/implementation_depression/depression_modelsave/resnet50_test.py yw4554@hpc.shanghai.nyu.edu:/scratch/yw4554/im_de_url/implementation_depression
#scp /users/mac/desktop/implementation_depression/depression_modelsave/resnet50_test.py yw4554@hpc.shanghai.nyu.edu:/scratch/yw4554/im_de_url/implementation_depression
#scp /Users/mac/Desktop/implementation_depression/depression_modelsave/resnet50_server.py yw4554@greene.hpc.nyu.edu:/scratch/yw4554/im_de_url/implementation_depression
#scp -r yw4554@hpc.shanghai.nyu.edu:/scratch/yw4554/im_de_url/implementation_depression/model_big /Users/mac/Desktop/implementation_depression/model_gpu
#scp /Users/mac/Desktop/implementation_depression/depression_modelsave/resnet50_server.py yw4554@hpc.shanghai.nyu.edu:/scratch/yw4554/im_de_url/implementation_depression


# %% [markdown]
# ## load model
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 743ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 808ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 454ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 469ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 278ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 286ms/step

# %%
biglst
# Out:
# [[5.057365894317627],
#  [2.4599103927612305],
#  [2.7102880477905273],
#  [10.500504493713379],
#  [3.7578375339508057],
#  [7.426548004150391],
#  [9.299671173095703],
#  [3.268017530441284],
#  [10.442290306091309],
#  [1.1419081687927246],
#  [3.5039796829223633],
#  [-0.26926708221435547],
#  [2.9812891483306885],
#  [5.665929317474365],
#  [3.180565357208252],
#  [0.2912691831588745],
#  [1.5513644218444824],
#  [4.386655807495117],
#  [6.120015621185303],
#  [3.6538400650024414],
#  [3.194768190383911],
#  [1.7401325702667236],
#  [2.772702217102051],
#  [1.4910814762115479],
#  [7.747043132781982],
#  [2.7829062938690186],
#  [-0.09309738874435425],
#  [3.628547191619873],
#  [3.5737688541412354],
#  [4.439402103424072],
#  [9.192000389099121],
#  [0.3139001131057739],
#  [1.5080976486206055],
#  [3.81615948677063],
#  [1.2502660751342773],
#  [1.9142080545425415],
#  [5.04820442199707],
#  [5.585550308227539],
#  [3.531128406524658],
#  [6.2575201988220215],
#  [1.8701376914978027],
#  [-0.729859471321106],
#  [1.8596937656402588],
#  [6.052730083465576],
#  [1.0566210746765137],
#  [1.1760077476501465],
#  [3.1067473888397217],
#  [0.5522457361221313],
#  [-1.0310542583465576],
#  [-0.4981483519077301],
#  [7.633864879608154],
#  [3.7883148193359375],
#  [3.745314359664917],
#  [3.3310062885284424],
#  [1.5864369869232178],
#  [3.6420836448669434],
#  [2.3069067001342773],
#  [0.9389341473579407],
#  [14.491083145141602],
#  [5.717038631439209],
#  [0.8067158460617065],
#  [4.529099464416504],
#  [2.639582395553589],
#  [3.6269643306732178],
#  [2.399042844772339],
#  [1.1786458492279053],
#  [7.605329990386963],
#  [7.3750386238098145],
#  [4.065465450286865],
#  [-0.3474689722061157],
#  [3.6460301876068115],
#  [2.1014976501464844],
#  [4.6312127113342285],
#  [5.295807838439941],
#  [0.9782847166061401],
#  [6.911076068878174],
#  [5.1134033203125],
#  [4.732369899749756],
#  [4.52940559387207],
#  [1.6931190490722656],
#  [3.1441550254821777],
#  [2.677194356918335],
#  [3.7454962730407715],
#  [5.070781230926514],
#  [2.865112543106079],
#  [1.5949257612228394],
#  [6.3758769035339355],
#  [3.9368033409118652],
#  [3.635108709335327],
#  [2.765592575073242],
#  [2.378943920135498],
#  [1.6035511493682861],
#  [0.7250662446022034],
#  [-0.5741430521011353],
#  [2.2712955474853516],
#  [8.76392650604248],
#  [3.2798407077789307],
#  [4.225272178649902],
#  [3.2903170585632324],
#  [-2.0814099311828613],
#  [7.1860833168029785],
#  [2.784115791320801],
#  [1.226369857788086],
#  [2.114581823348999],
#  [6.245595455169678],
#  [4.546766757965088],
#  [5.681447505950928],
#  [0.2676735818386078],
#  [6.904483795166016],
#  [3.0601494312286377],
#  [-0.4661507308483124],
#  [2.7440378665924072],
#  [-1.3769104480743408],
#  [2.67090106010437],
#  [3.304302930831909],
#  [2.191298484802246],
#  [6.223422050476074],
#  [2.1912569999694824],
#  [2.9861955642700195],
#  [3.0166873931884766],
#  [0.49477246403694153],
#  [0.8968873023986816],
#  [5.56633996963501],
#  [3.4459338188171387],
#  [2.5268404483795166],
#  [6.314373016357422],
#  [2.3613641262054443],
#  [5.713179588317871],
#  [12.306763648986816],
#  [6.963686943054199],
#  [2.4909207820892334],
#  [4.551232814788818],
#  [3.053565502166748],
#  [0.5891424417495728],
#  [4.81630802154541],
#  [5.926387786865234],
#  [2.790022611618042],
#  [1.5720654726028442],
#  [2.8209388256073],
#  [5.95820426940918],
#  [2.539874792098999],
#  [1.9452381134033203],
#  [3.032546043395996],
#  [2.3069682121276855],
#  [6.922381401062012],
#  [1.5727291107177734],
#  [3.987703800201416],
#  [5.536418914794922],
#  [2.982619285583496],
#  [3.8172876834869385],
#  [0.45882248878479004],
#  [3.732011556625366],
#  [2.0748794078826904],
#  [2.3740956783294678],
#  [1.5513644218444824],
#  [4.159465312957764],
#  [5.322350978851318],
#  [4.915474891662598],
#  [6.421138763427734],
#  [2.1710331439971924],
#  [0.9386794567108154],
#  [9.663256645202637],
#  [3.9122488498687744],
#  [-0.22110453248023987],
#  [0.6049614548683167],
#  [4.506464958190918],
#  [3.102489709854126],
#  [7.089516639709473],
#  [18.889816284179688],
#  [1.3275278806686401],
#  [4.098367691040039],
#  [3.604003667831421],
#  [9.168105125427246],
#  [3.0395290851593018],
#  [7.389768123626709],
#  [-0.2342395931482315],
#  [2.2721190452575684],
#  [6.768253803253174],
#  [1.6116011142730713],
#  [1.8018845319747925],
#  [0.803747832775116],
#  [4.0997514724731445],
#  [3.458256483078003],
#  [3.8374733924865723],
#  [3.925036668777466],
#  [0.22317847609519958],
#  [6.566010475158691],
#  [8.511679649353027],
#  [3.5117619037628174],
#  [2.0552992820739746],
#  [8.095829010009766],
#  [7.897648334503174],
#  [2.5039167404174805],
#  [1.2923918962478638],
#  [2.0692055225372314],
#  [2.50026273727417],
#  [1.2262659072875977],
#  [1.5328726768493652],
#  [5.947134971618652],
#  [1.2095301151275635],
#  [4.841958522796631],
#  [-0.14617115259170532],
#  [1.7331732511520386],
#  [12.631804466247559],
#  [-1.0914020538330078],
#  [2.087054491043091],
#  [1.0862069129943848],
#  [2.0600662231445312],
#  [10.8956880569458],
#  [2.531097412109375],
#  [3.0429396629333496],
#  [1.8938835859298706],
#  [1.4870328903198242],
#  [1.1813607215881348],
#  [6.1441264152526855],
#  [11.144421577453613],
#  [6.308290481567383],
#  [3.7136547565460205],
#  [0.8355396389961243],
#  [-1.425895094871521],
#  [4.955479145050049],
#  [3.0682528018951416],
#  [1.6039561033248901],
#  [2.3231797218322754],
#  [5.722316265106201],
#  [3.5805187225341797]]

# %%
import csv
video_name='203_1_Freeform_video'
with open("feature_ResNet50_server.csv",'w') as f:
    
    write = csv.writer(f)
    write.writerow(field)

   
    for i in range(len(biglst)):
        

        newlst=[video_name,str(i)]
        
        newlst+=biglst[i]
            
      
        write.writerow(newlst)
    
f.close()
